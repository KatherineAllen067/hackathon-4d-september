# %% [markdown]
# # Skip the Dishes Hackathon

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This notebook is for reviewing the data on SkipTheDishes.

# %%
df_supply = pd.read_csv('~/Downloads/FoodSupplyandDisposition_CA_1960-2018.csv')

# %%
df_supply
# Out:
#        REF_DATE                    Commodity         UOM  Beginning stocks  \
# 0          1960  Ale, beer, stout and porter  Kilolitres               NaN
# 1          1960                  Apple juice      Tonnes             28.57
# 2          1960                  Apple sauce      Tonnes              6.37
# 3          1960                Apples canned      Tonnes              4.33
# 4          1960                 Apples dried      Tonnes               NaN
# ...         ...                          ...         ...               ...
# 10985      2018                  Wheat flour      Tonnes             33.31
# 10986      2018    Whipping cream 32% or 35%  Kilolitres               NaN
# 10987      2018                        Wines  Kilolitres               NaN
# 10988      2018           Wintermelons fresh      Tonnes               NaN
# 10989      2018                       Yogurt  Kilolitres               NaN
#
#        Domestic disappearance  Ending stocks  Exports  Imports  Manufacturing  \
# 0                     1070.44            NaN      NaN      NaN            NaN
# 1                       38.54          22.49     1.29      NaN            NaN
# 2                        6.70           4.67      NaN      NaN            NaN
# 3                        4.79           4.86     0.41      NaN            NaN
# 4                        0.54            NaN      NaN     0.54            NaN
# ...                       ...            ...      ...      ...            ...
# 10985                 2089.88          28.21   255.73    88.91          87.08
# 10986                   59.39            NaN      NaN      NaN            NaN
# 10987                  530.63            NaN    90.38   415.01            NaN
# 10988                    1.90            NaN      NaN     2.06            NaN
# 10989                  365.70            NaN     9.24     0.55            NaN
#
#        Production  Total disposition  Total supply  Waste
# 0             NaN               0.00           NaN    NaN
# 1           33.75              23.78         62.32    NaN
# 2            5.00               6.70         11.37    NaN
# 3            5.73                NaN         10.06    NaN
# 4             NaN               0.54          0.54    NaN
# ...           ...                ...           ...    ...
# 10985     2338.68            2432.69       2460.89   0.00
# 10986       59.39              59.39         59.39    NaN
# 10987         NaN             621.00           NaN    NaN
# 10988         NaN               2.06          2.06   0.17
# 10989      374.38             374.94        374.94    NaN
#
# [10990 rows x 13 columns]

# %%
df_supply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10990 entries, 0 to 10989
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   REF_DATE                10990 non-null  int64
#  1   Commodity               10990 non-null  object
#  2   UOM                     10990 non-null  object
#  3   Beginning stocks        3490 non-null   float64
#  4   Domestic disappearance  9307 non-null   float64
#  5   Ending stocks           3454 non-null   float64
#  6   Exports                 5764 non-null   float64
#  7   Imports                 8561 non-null   float64
#  8   Manufacturing           2260 non-null   float64
#  9   Production              6629 non-null   float64
#  10  Total disposition       10723 non-null  float64
#  11  Total supply            9589 non-null   float64
#  12  Waste                   4034 non-null   float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
(df_supply.isna().sum()/ df_supply.shape[0]) *100
# Out:
# REF_DATE                   0.000000
# Commodity                  0.000000
# UOM                        0.000000
# Beginning stocks          68.243858
# Domestic disappearance    15.313922
# Ending stocks             68.571429
# Exports                   47.552320
# Imports                   22.101911
# Manufacturing             79.435851
# Production                39.681529
# Total disposition          2.429481
# Total supply              12.747953
# Waste                     63.293904
# dtype: float64

# %%
df_yelp = pd.read_csv('~/Downloads/Yelp_TO_restaurant_reviews.csv')

# %%
df_yelp.sample(5)
# Out:
#                             name                address postal_code  \
# 245275                La Carnita        106 John Street     M5H 1X9
# 215152  Carole's Cheesecake Cafe  114 Cumberland Street     M5R 1A6
# 317096        One Hour Cafeteria     435 Spadina Avenue     M5T 2G6
# 312992               Smith Bros.      880 Warden Avenue     M1L 4W6
# 233626            Sansotei Ramen    179 Dundas Street W     M5G 1Z8
#
#          latitude  longitude  stars_x  review_count  is_open  \
# 245275  43.647585 -79.390389      3.5           317        1
# 215152  43.670288 -79.391641      3.5           182        1
# 317096  43.657414 -79.399357      3.5           101        0
# 312992  43.728887 -79.288223      4.0           286        1
# 233626  43.655004 -79.386473      4.0           794        1
#
#                                                attributes  \
# 245275  {'BikeParking': 'True', 'RestaurantsTakeOut': ...
# 215152  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...
# 317096  {'BikeParking': 'True', 'Ambience': "{'romanti...
# 312992  {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# 233626  {'NoiseLevel': "u'average'", 'RestaurantsAttir...
#
#                                                categories  \
# 245275                               Mexican, Restaurants
# 215152                           Desserts, Food, Bakeries
# 317096  Asian Fusion, Food, Restaurants, Chinese, Juic...
# 312992  Restaurants, Nightlife, Steakhouses, American ...
# 233626              Restaurants, Ramen, Japanese, Noodles
#
#                                                     hours  stars_y  useful  \
# 245275  {'Monday': '11:30-22:0', 'Tuesday': '11:30-23:...        3       0
# 215152  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        3       1
# 317096  {'Monday': '12:0-22:30', 'Tuesday': '12:0-22:3...        2       0
# 312992  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...        4       0
# 233626  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        5       0
#
#         funny  cool                                               text  \
# 245275      0     0  I've been going to this place for a while now ...
# 215152      0     0  Tried pistachio and strawberry cheesecake, ita...
# 317096      0     0  BEAN BAGS. Dirty bean bags? OK place to hang o...
# 312992      0     0  We came here for mother's day on Saturday and ...
# 233626      0     0  Had the tonkotsu ramen with extra tonkatsu, an...
#
#                        date
# 245275  2017-11-23 06:06:46
# 215152  2015-10-25 18:14:21
# 317096  2017-09-04 06:45:45
# 312992  2017-05-16 02:04:02
# 233626  2015-10-16 07:17:22

# %%
df_yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422049 entries, 0 to 422048
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          422049 non-null  object
#  1   address       421601 non-null  object
#  2   postal_code   421749 non-null  object
#  3   latitude      422049 non-null  float64
#  4   longitude     422049 non-null  float64
#  5   stars_x       422049 non-null  float64
#  6   review_count  422049 non-null  int64
#  7   is_open       422049 non-null  int64
#  8   attributes    418953 non-null  object
#  9   categories    422049 non-null  object
#  10  hours         385287 non-null  object
#  11  stars_y       422049 non-null  int64
#  12  useful        422049 non-null  int64
#  13  funny         422049 non-null  int64
#  14  cool          422049 non-null  int64
#  15  text          422049 non-null  object
#  16  date          422049 non-null  object
# dtypes: float64(3), int64(6), object(8)
# memory usage: 54.7+ MB

# %%
(df_yelp.isna().sum()/ df_yelp.shape[0]) *100
# Out:
# name            0.000000
# address         0.106149
# postal_code     0.071082
# latitude        0.000000
# longitude       0.000000
# stars_x         0.000000
# review_count    0.000000
# is_open         0.000000
# attributes      0.733564
# categories      0.000000
# hours           8.710363
# stars_y         0.000000
# useful          0.000000
# funny           0.000000
# cool            0.000000
# text            0.000000
# date            0.000000
# dtype: float64

# %%
df_yelp = df_yelp.loc[df_yelp['is_open'] == 1]

# %%
df_yelp.drop(["hours", "is_open"], axis=1, inplace = True)

# %%
df_yelp.reset_index(drop = True, inplace = True)

# %%
df_yelp
# Out:
#                  name                      address postal_code   latitude  \
# 0       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 1       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 2       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 3       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 4       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# ...               ...                          ...         ...        ...
# 343228   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343229   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343230   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343231   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343232   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
#
#         longitude  stars_x  review_count  \
# 0      -79.349548      4.5             8
# 1      -79.349548      4.5             8
# 2      -79.349548      4.5             8
# 3      -79.349548      4.5             8
# 4      -79.349548      4.5             8
# ...           ...      ...           ...
# 343228 -79.384809      4.0           113
# 343229 -79.384809      4.0           113
# 343230 -79.384809      4.0           113
# 343231 -79.384809      4.0           113
# 343232 -79.384809      4.0           113
#
#                                                attributes         categories  \
# 0       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 1       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 2       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 3       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 4       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# ...                                                   ...                ...
# 343228  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343229  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343230  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343231  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343232  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
#
#         stars_y  useful  funny  cool  \
# 0             3       1      0     1
# 1             5       2      0     2
# 2             4       0      0     0
# 3             5       0      0     0
# 4             5      10      6     8
# ...         ...     ...    ...   ...
# 343228        4       1      0     2
# 343229        3       0      0     0
# 343230        3       0      0     0
# 343231        4       0      0     0
# 343232        5       2      0     0
#
#                                                      text                 date
# 0       Oh? Another patbingsu review? This one was bet...  2017-07-30 23:32:27
# 1       What really earns them their 5 stars is the un...  2016-01-31 16:19:16
# 2       Located inside the Galleria Supermarket.\nStop...  2016-04-29 03:43:54
# 3       Yummy cakes! U should try their sweet potato c...  2017-06-13 23:42:37
# 4       One of my favorite bakeries! This bakery is in...  2016-01-26 22:56:47
# ...                                                   ...                  ...
# 343228  I've been here a few times. Almost every time ...  2018-04-17 10:43:30
# 343229  I've came here for lunch several times and it ...  2017-11-17 18:12:45
# 343230  I feel mean leaving this review because servic...  2018-10-25 02:11:36
# 343231  Decent price for lunch, after tax comes to $10...  2016-06-09 20:42:58
# 343232  I've been waiting for a new Thai restaurant in...  2017-05-24 18:40:57
#
# [343233 rows x 15 columns]

# %%
number_of_branches = df_yelp.groupby(by = 'name')['address'].nunique().sort_values(ascending = False)

number_of_branches
# Out:
# name
# Starbucks                                 129
# Tim Hortons                                94
# McDonald's                                 44
# Subway                                     43
# Pizza Pizza                                33
#                                          ...
# Choco Churros                               0
# Urban Smoke Fusion BBQ Food Truck           0
# Beer & Liquor Delivery Service Toronto      0
# Culinary Adventure                          0
# Per Se Mobile                               0
# Name: address, Length: 5241, dtype: int64

# %%
df_yelp.loc[df_yelp['name'] == 'Choco Churros']
# Out:
#                  name address postal_code   latitude  longitude  stars_x  \
# 271918  Choco Churros    None         NaN  43.653226 -79.383184      3.5
# 271919  Choco Churros    None         NaN  43.653226 -79.383184      3.5
# 271920  Choco Churros    None         NaN  43.653226 -79.383184      3.5
# 271921  Choco Churros    None         NaN  43.653226 -79.383184      3.5
# 271922  Choco Churros    None         NaN  43.653226 -79.383184      3.5
# 271923  Choco Churros    None         NaN  43.653226 -79.383184      3.5
#
#         review_count                                         attributes  \
# 271918             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 271919             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 271920             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 271921             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 271922             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
# 271923             5  {'RestaurantsPriceRange2': '1', 'BikeParking':...
#
#                categories  stars_y  useful  funny  cool  \
# 271918  Food Trucks, Food        4       1      0     1
# 271919  Food Trucks, Food        4       0      0     0
# 271920  Food Trucks, Food        3       0      0     0
# 271921  Food Trucks, Food        4       4      1     1
# 271922  Food Trucks, Food        2       1      1     0
# 271923  Food Trucks, Food        5       1      0     0
#
#                                                      text                 date
# 271918  Great little treat for $5 bucks.  I had the tr...  2013-08-16 18:51:39
# 271919  Just tried for the very first time at the food...  2013-08-07 16:12:59
# 271920  Not really much to rave here.  It was just ok....  2013-08-21 03:57:50
# 271921  Churros on wheels!  Genious!  \n\nPlain old ci...  2013-05-14 18:46:26
# 271922  Ordered the same again today.  This time they ...  2013-08-09 15:57:17
# 271923  My favourite dessert from my favourite food tr...  2016-03-06 18:24:03

# %%
#check other grouping possibilities
df_yelp.groupby(by = ['address','name']).mean()
# Out:
#                                                                        latitude  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii            43.646506
# , unit 2                                           HelloFresh         43.641701
# 1 Adelaide St E                                    Starbucks          43.650161
#                                                    Touch              43.650559
# 1 Adelaide Street E                                Craft Beer Market  43.650159
# ...                                                                         ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground    43.774084
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi        43.774208
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks          43.726192
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi        43.724684
# Yorkdale Shopping Mall                             Amaya Express      43.725686
#
#                                                                       longitude  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii           -79.380145
# , unit 2                                           HelloFresh        -79.421299
# 1 Adelaide St E                                    Starbucks         -79.377797
#                                                    Touch             -79.377641
# 1 Adelaide Street E                                Craft Beer Market -79.378093
# ...                                                                         ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground   -79.502381
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi       -79.498333
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks         -79.455518
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi       -79.454173
# Yorkdale Shopping Mall                             Amaya Express     -79.450441
#
#                                                                       stars_x  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii                2.5
# , unit 2                                           HelloFresh             2.5
# 1 Adelaide St E                                    Starbucks              3.5
#                                                    Touch                  2.5
# 1 Adelaide Street E                                Craft Beer Market      3.0
# ...                                                                       ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground        2.5
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi            4.0
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks              4.0
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi            2.5
# Yorkdale Shopping Mall                             Amaya Express          2.5
#
#                                                                       review_count  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii                     3.0
# , unit 2                                           HelloFresh                  6.0
# 1 Adelaide St E                                    Starbucks                   6.0
#                                                    Touch                      16.0
# 1 Adelaide Street E                                Craft Beer Market          81.0
# ...                                                                            ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground            25.0
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi                 7.0
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks                  12.0
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi                 5.0
# Yorkdale Shopping Mall                             Amaya Express              45.0
#
#                                                                        stars_y  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii            2.333333
# , unit 2                                           HelloFresh         3.000000
# 1 Adelaide St E                                    Starbucks          3.666667
#                                                    Touch              2.687500
# 1 Adelaide Street E                                Craft Beer Market  3.098765
# ...                                                                        ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground    2.560000
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi        3.857143
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks          3.750000
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi        2.400000
# Yorkdale Shopping Mall                             Amaya Express      2.266667
#
#                                                                         useful  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii            0.666667
# , unit 2                                           HelloFresh         1.142857
# 1 Adelaide St E                                    Starbucks          1.333333
#                                                    Touch              0.875000
# 1 Adelaide Street E                                Craft Beer Market  0.716049
# ...                                                                        ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground    0.880000
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi        0.428571
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks          0.583333
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi        1.600000
# Yorkdale Shopping Mall                             Amaya Express      1.133333
#
#                                                                          funny  \
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii            0.000000
# , unit 2                                           HelloFresh         0.285714
# 1 Adelaide St E                                    Starbucks          0.333333
#                                                    Touch              0.250000
# 1 Adelaide Street E                                Craft Beer Market  0.123457
# ...                                                                        ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground    0.320000
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi        0.000000
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks          0.166667
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi        0.400000
# Yorkdale Shopping Mall                             Amaya Express      0.311111
#
#                                                                           cool
# address                                            name
# , 200 Bay Street, Unit L5                          Freshii            0.000000
# , unit 2                                           HelloFresh         0.142857
# 1 Adelaide St E                                    Starbucks          0.333333
#                                                    Touch              0.312500
# 1 Adelaide Street E                                Craft Beer Market  0.419753
# ...                                                                        ...
# York Student Centre, 4700 Keele Street, Lower L... The Underground    0.720000
# York U Student Centre, 4700 Keele Street, 2nd F... Mac's Sushi        0.142857
# Yorkdale Shopping Center, 3401 Dufferin Street     Starbucks          0.166667
# Yorkdale Shopping Centre, 3401 Dufferin Street     Mac's Sushi        0.800000
# Yorkdale Shopping Mall                             Amaya Express      0.333333
#
# [6795 rows x 8 columns]

# %%
df_yelp.loc[80, 'attributes']
# Out:
# '{\'RestaurantsPriceRange2\': \'2\', \'HasTV\': \'False\', \'BikeParking\': \'True\', \'OutdoorSeating\': \'False\', \'RestaurantsAttire\': "u\'casual\'", \'GoodForKids\': \'False\', \'Ambience\': "{\'romantic\': False, \'intimate\': False, \'classy\': False, \'hipster\': False, \'divey\': False, \'touristy\': False, \'trendy\': False, \'upscale\': False, \'casual\': False}", \'NoiseLevel\': "u\'quiet\'", \'RestaurantsReservations\': \'True\', \'GoodForMeal\': "{\'dessert\': False, \'latenight\': False, \'lunch\': False, \'dinner\': True, \'brunch\': False, \'breakfast\': False}", \'BusinessParking\': "{\'garage\': False, \'street\': True, \'validated\': False, \'lot\': False, \'valet\': False}", \'RestaurantsGoodForGroups\': \'True\', \'RestaurantsTableService\': \'True\', \'Alcohol\': "u\'full_bar\'"}'

# %%
df_yelp
# Out:
#                  name                      address postal_code   latitude  \
# 0       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 1       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 2       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 3       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 4       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# ...               ...                          ...         ...        ...
# 343228   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343229   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343230   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343231   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 343232   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
#
#         longitude  stars_x  review_count  \
# 0      -79.349548      4.5             8
# 1      -79.349548      4.5             8
# 2      -79.349548      4.5             8
# 3      -79.349548      4.5             8
# 4      -79.349548      4.5             8
# ...           ...      ...           ...
# 343228 -79.384809      4.0           113
# 343229 -79.384809      4.0           113
# 343230 -79.384809      4.0           113
# 343231 -79.384809      4.0           113
# 343232 -79.384809      4.0           113
#
#                                                attributes         categories  \
# 0       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 1       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 2       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 3       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 4       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# ...                                                   ...                ...
# 343228  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343229  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343230  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343231  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 343232  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
#
#         stars_y  useful  funny  cool  \
# 0             3       1      0     1
# 1             5       2      0     2
# 2             4       0      0     0
# 3             5       0      0     0
# 4             5      10      6     8
# ...         ...     ...    ...   ...
# 343228        4       1      0     2
# 343229        3       0      0     0
# 343230        3       0      0     0
# 343231        4       0      0     0
# 343232        5       2      0     0
#
#                                                      text                 date
# 0       Oh? Another patbingsu review? This one was bet...  2017-07-30 23:32:27
# 1       What really earns them their 5 stars is the un...  2016-01-31 16:19:16
# 2       Located inside the Galleria Supermarket.\nStop...  2016-04-29 03:43:54
# 3       Yummy cakes! U should try their sweet potato c...  2017-06-13 23:42:37
# 4       One of my favorite bakeries! This bakery is in...  2016-01-26 22:56:47
# ...                                                   ...                  ...
# 343228  I've been here a few times. Almost every time ...  2018-04-17 10:43:30
# 343229  I've came here for lunch several times and it ...  2017-11-17 18:12:45
# 343230  I feel mean leaving this review because servic...  2018-10-25 02:11:36
# 343231  Decent price for lunch, after tax comes to $10...  2016-06-09 20:42:58
# 343232  I've been waiting for a new Thai restaurant in...  2017-05-24 18:40:57
#
# [343233 rows x 15 columns]

# %%
df_yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343233 entries, 0 to 343232
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          343233 non-null  object
#  1   address       342853 non-null  object
#  2   postal_code   342949 non-null  object
#  3   latitude      343233 non-null  float64
#  4   longitude     343233 non-null  float64
#  5   stars_x       343233 non-null  float64
#  6   review_count  343233 non-null  int64
#  7   attributes    340466 non-null  object
#  8   categories    343233 non-null  object
#  9   stars_y       343233 non-null  int64
#  10  useful        343233 non-null  int64
#  11  funny         343233 non-null  int64
#  12  cool          343233 non-null  int64
#  13  text          343233 non-null  object
#  14  date          343233 non-null  object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 39.3+ MB

# %%
df_yelp = df_yelp[df_yelp['attributes'].notna()]

# %%
df_yelp.reset_index(drop = True, inplace = True)

# %%
#import ast

#ast.literal_eval(df_yelp['attributes'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-4045ab6217ab> in <module>
#       1 import ast
#       2
# ----> 3 ast.literal_eval(df_yelp['attributes'])
#
# ~\anaconda3\lib\ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# ~\anaconda3\lib\ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
#      91     return _convert(node_or_string)
#      92
#
# ~\anaconda3\lib\ast.py in _convert_signed_num(node)
#      61             else:
#      62                 return - operand
# ---> 63         return _convert_num(node)
#      64     def _convert(node):
#      65         if isinstance(node, Constant):
#
# ~\anaconda3\lib\ast.py in _convert_num(node)
#      53         elif isinstance(node, Num):
#      54             return node.n
# ---> 55         raise ValueError('malformed node or string: ' + repr(node))
#      56     def _convert_signed_num(node):
#      57         if isinstance(node, UnaryOp) and isinstance(node.op, (UAdd, USub)):
#
# ValueError: malformed node or string: 0         {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 1         {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 2         {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 3         {'RestaurantsDelivery': 'False', 'RestaurantsP...
# 4         {'RestaurantsDelivery': 'False', 'RestaurantsP...
#                                 ...
# 340461    {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 340462    {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 340463    {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 340464    {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# 340465    {'RestaurantsPriceRange2': '2', 'RestaurantsGo...
# Name: attributes, Length: 340466, dtype: object

# %%
df_yelp['attributes'][0]
# Out:
# '{\'RestaurantsDelivery\': \'False\', \'RestaurantsPriceRange2\': \'2\', \'RestaurantsTakeOut\': \'True\', \'BikeParking\': \'True\', \'BusinessParking\': "{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': False, \'valet\': False}"}'

# %%
#import json

#attr = json.loads(df_yelp['attributes'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-55d536644648> in <module>
#       1 import json
#       2
# ----> 3 attr = json.loads(df_yelp['attributes'])
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not Series

# %%
local_in_review = []

for text in df_yelp['text']:
    if "local" in text:
        local_in_review.append(1)
    elif "Local" in text:
        local_in_review.append(1)
    elif "locals" in text:
        local_in_review.append(1)
    elif "Locals" in text:
        local_in_review.append(1)
    else:
        local_in_review.append(0)

# %%
# check length
len(local_in_review)
# Out:
# 340466

# %%
df_local = pd.DataFrame({'local_in_review': local_in_review})

#check
df_local
# Out:
#         local_in_review
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 340461                0
# 340462                0
# 340463                0
# 340464                0
# 340465                0
#
# [340466 rows x 1 columns]

# %%
df_yelp = pd.concat([df_yelp, df_local], axis=1)

# %%
# check
df_yelp
# Out:
#                  name                      address postal_code   latitude  \
# 0       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 1       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 2       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 3       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 4       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# ...               ...                          ...         ...        ...
# 340461   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340462   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340463   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340464   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340465   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
#
#         longitude  stars_x  review_count  \
# 0      -79.349548      4.5             8
# 1      -79.349548      4.5             8
# 2      -79.349548      4.5             8
# 3      -79.349548      4.5             8
# 4      -79.349548      4.5             8
# ...           ...      ...           ...
# 340461 -79.384809      4.0           113
# 340462 -79.384809      4.0           113
# 340463 -79.384809      4.0           113
# 340464 -79.384809      4.0           113
# 340465 -79.384809      4.0           113
#
#                                                attributes         categories  \
# 0       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 1       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 2       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 3       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 4       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# ...                                                   ...                ...
# 340461  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340462  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340463  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340464  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340465  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
#
#         stars_y  useful  funny  cool  \
# 0             3       1      0     1
# 1             5       2      0     2
# 2             4       0      0     0
# 3             5       0      0     0
# 4             5      10      6     8
# ...         ...     ...    ...   ...
# 340461        4       1      0     2
# 340462        3       0      0     0
# 340463        3       0      0     0
# 340464        4       0      0     0
# 340465        5       2      0     0
#
#                                                      text  \
# 0       Oh? Another patbingsu review? This one was bet...
# 1       What really earns them their 5 stars is the un...
# 2       Located inside the Galleria Supermarket.\nStop...
# 3       Yummy cakes! U should try their sweet potato c...
# 4       One of my favorite bakeries! This bakery is in...
# ...                                                   ...
# 340461  I've been here a few times. Almost every time ...
# 340462  I've came here for lunch several times and it ...
# 340463  I feel mean leaving this review because servic...
# 340464  Decent price for lunch, after tax comes to $10...
# 340465  I've been waiting for a new Thai restaurant in...
#
#                        date  local_in_review
# 0       2017-07-30 23:32:27                0
# 1       2016-01-31 16:19:16                0
# 2       2016-04-29 03:43:54                0
# 3       2017-06-13 23:42:37                0
# 4       2016-01-26 22:56:47                0
# ...                     ...              ...
# 340461  2018-04-17 10:43:30                0
# 340462  2017-11-17 18:12:45                0
# 340463  2018-10-25 02:11:36                0
# 340464  2016-06-09 20:42:58                0
# 340465  2017-05-24 18:40:57                0
#
# [340466 rows x 16 columns]

# %%
# check how many reviews have local in them
df_yelp['local_in_review'].value_counts()
# Out:
# 0    332230
# 1      8236
# Name: local_in_review, dtype: int64

# %%
type(df_yelp['date'][0])
# Out:
# str

# %%
# converting the date object to a datetime type
df_yelp['date'] = pd.to_datetime(df_yelp['date'], infer_datetime_format=True)

# converting the date column into year, month, day columns
df_yelp['review_year'] = df_yelp['date'].dt.year
df_yelp['review_month'] = df_yelp['date'].dt.month
df_yelp['review_day'] = df_yelp['date'].dt.day

df_yelp
# Out:
#                  name                      address postal_code   latitude  \
# 0       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 1       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 2       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 3       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 4       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# ...               ...                          ...         ...        ...
# 340461   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340462   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340463   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340464   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340465   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
#
#         longitude  stars_x  review_count  \
# 0      -79.349548      4.5             8
# 1      -79.349548      4.5             8
# 2      -79.349548      4.5             8
# 3      -79.349548      4.5             8
# 4      -79.349548      4.5             8
# ...           ...      ...           ...
# 340461 -79.384809      4.0           113
# 340462 -79.384809      4.0           113
# 340463 -79.384809      4.0           113
# 340464 -79.384809      4.0           113
# 340465 -79.384809      4.0           113
#
#                                                attributes         categories  \
# 0       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 1       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 2       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 3       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 4       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# ...                                                   ...                ...
# 340461  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340462  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340463  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340464  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340465  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
#
#         stars_y  useful  funny  cool  \
# 0             3       1      0     1
# 1             5       2      0     2
# 2             4       0      0     0
# 3             5       0      0     0
# 4             5      10      6     8
# ...         ...     ...    ...   ...
# 340461        4       1      0     2
# 340462        3       0      0     0
# 340463        3       0      0     0
# 340464        4       0      0     0
# 340465        5       2      0     0
#
#                                                      text                date  \
# 0       Oh? Another patbingsu review? This one was bet... 2017-07-30 23:32:27
# 1       What really earns them their 5 stars is the un... 2016-01-31 16:19:16
# 2       Located inside the Galleria Supermarket.\nStop... 2016-04-29 03:43:54
# 3       Yummy cakes! U should try their sweet potato c... 2017-06-13 23:42:37
# 4       One of my favorite bakeries! This bakery is in... 2016-01-26 22:56:47
# ...                                                   ...                 ...
# 340461  I've been here a few times. Almost every time ... 2018-04-17 10:43:30
# 340462  I've came here for lunch several times and it ... 2017-11-17 18:12:45
# 340463  I feel mean leaving this review because servic... 2018-10-25 02:11:36
# 340464  Decent price for lunch, after tax comes to $10... 2016-06-09 20:42:58
# 340465  I've been waiting for a new Thai restaurant in... 2017-05-24 18:40:57
#
#         local_in_review  review_year  review_month  review_day
# 0                     0         2017             7          30
# 1                     0         2016             1          31
# 2                     0         2016             4          29
# 3                     0         2017             6          13
# 4                     0         2016             1          26
# ...                 ...          ...           ...         ...
# 340461                0         2018             4          17
# 340462                0         2017            11          17
# 340463                0         2018            10          25
# 340464                0         2016             6           9
# 340465                0         2017             5          24
#
# [340466 rows x 19 columns]

# %%
#drop the 'date' column
df_yelp.drop(['date'], axis=1, inplace=True)

# %%
# check if attributes remain the same for restaurants
print(df_yelp['attributes'][0])
print(df_yelp['attributes'][1])
print(df_yelp['attributes'][2])
print(df_yelp['attributes'][3])
# Out:
# {'RestaurantsDelivery': 'False', 'RestaurantsPriceRange2': '2', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}
# {'RestaurantsDelivery': 'False', 'RestaurantsPriceRange2': '2', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}
# {'RestaurantsDelivery': 'False', 'RestaurantsPriceRange2': '2', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}
# {'RestaurantsDelivery': 'False', 'RestaurantsPriceRange2': '2', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}

# %%
# check if categories remain the same for restaurants
print(df_yelp['categories'][0])
print(df_yelp['categories'][1])
print(df_yelp['categories'][2])
print(df_yelp['categories'][3])
# Out:
# Bakeries, Food
# Bakeries, Food
# Bakeries, Food
# Bakeries, Food

# %%
df_restaurants = df_yelp.drop(['stars_y', 'useful', 'funny', 'cool', 'text',
             'review_year', 'review_month', 'review_day'], axis=1)

df_restaurants
# Out:
#                  name                      address postal_code   latitude  \
# 0       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 1       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 2       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 3       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# 4       Bakery Gateau  865 York Mills Road, Unit 1     M3B 1Y6  43.754093
# ...               ...                          ...         ...        ...
# 340461   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340462   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340463   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340464   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
# 340465   Thai Fantasy             578 Yonge Street     M4Y 1Z3  43.665120
#
#         longitude  stars_x  review_count  \
# 0      -79.349548      4.5             8
# 1      -79.349548      4.5             8
# 2      -79.349548      4.5             8
# 3      -79.349548      4.5             8
# 4      -79.349548      4.5             8
# ...           ...      ...           ...
# 340461 -79.384809      4.0           113
# 340462 -79.384809      4.0           113
# 340463 -79.384809      4.0           113
# 340464 -79.384809      4.0           113
# 340465 -79.384809      4.0           113
#
#                                                attributes         categories  \
# 0       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 1       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 2       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 3       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# 4       {'RestaurantsDelivery': 'False', 'RestaurantsP...     Bakeries, Food
# ...                                                   ...                ...
# 340461  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340462  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340463  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340464  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
# 340465  {'RestaurantsPriceRange2': '2', 'RestaurantsGo...  Restaurants, Thai
#
#         local_in_review
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 340461                0
# 340462                0
# 340463                0
# 340464                0
# 340465                0
#
# [340466 rows x 10 columns]

# %%
#check other grouping possibilities
df_restaurants.groupby(by = ['name']).mean()
# Out:
#                                latitude  longitude  stars_x  review_count  \
# name
# 'ONO Poké Bar                 43.639526 -79.415855      4.0     82.000000
# 00 Gelato                     43.646312 -79.391329      4.5     61.000000
# 0109 Dessert & Chocolate      43.814494 -79.294924      3.5    194.000000
# 1 Plus 2 Pizza & Wings        43.597394 -79.520640      2.0      5.000000
# 100 Percent Korean            43.825482 -79.298528      4.5    191.000000
# ...                                 ...        ...      ...           ...
# pico de gallo                 43.654775 -79.402205      3.5      5.000000
# süüp health bar               43.659241 -79.382860      3.5     23.000000
# teashop 168                   43.657685 -79.402360      3.5      5.000000
# yuan yuan Chinese Restaurant  43.791998 -79.250489      3.5      3.000000
# z-teca Gourmet Burritos       43.673038 -79.404180      2.5     34.689655
#
#                               local_in_review
# name
# 'ONO Poké Bar                        0.012048
# 00 Gelato                            0.015873
# 0109 Dessert & Chocolate             0.010000
# 1 Plus 2 Pizza & Wings               0.000000
# 100 Percent Korean                   0.010363
# ...                                       ...
# pico de gallo                        0.000000
# süüp health bar                      0.043478
# teashop 168                          0.000000
# yuan yuan Chinese Restaurant         0.000000
# z-teca Gourmet Burritos              0.000000
#
# [4959 rows x 5 columns]

# %%
df_restaurants.groupby(by = ['name', 'address', 'postal_code']).mean()
# Out:
#                                                                                           latitude  \
# name                     address                                            postal_code
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2      43.639526
# 00 Gelato                370 King Street W                                  M5V 1J9      43.646312
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3      43.814494
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9      43.597394
# 100 Percent Korean       4779 Steeles Avenue E                              M1V          43.825482
# ...                                                                                            ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8      43.643090
#                          327 King St W                                      M5V 1J5      43.646085
#                          Commerce Court, 199 Bay St                         M5L 1E2      43.648133
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8      43.768778
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3      43.778045
#
#                                                                                          longitude  \
# name                     address                                            postal_code
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     -79.415855
# 00 Gelato                370 King Street W                                  M5V 1J9     -79.391329
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     -79.294924
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     -79.520640
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         -79.298528
# ...                                                                                            ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     -79.383072
#                          327 King St W                                      M5V 1J5     -79.391092
#                          Commerce Court, 199 Bay St                         M5L 1E2     -79.379509
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     -79.413419
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     -79.495472
#
#                                                                                          stars_x  \
# name                     address                                            postal_code
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2          4.0
# 00 Gelato                370 King Street W                                  M5V 1J9          4.5
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3          3.5
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9          2.0
# 100 Percent Korean       4779 Steeles Avenue E                              M1V              4.5
# ...                                                                                          ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8          2.5
#                          327 King St W                                      M5V 1J5          2.5
#                          Commerce Court, 199 Bay St                         M5L 1E2          2.5
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8          2.5
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3          2.5
#
#                                                                                          review_count  \
# name                     address                                            postal_code
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2              82.0
# 00 Gelato                370 King Street W                                  M5V 1J9              61.0
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3             194.0
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9               5.0
# 100 Percent Korean       4779 Steeles Avenue E                              M1V                 191.0
# ...                                                                                               ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8              10.0
#                          327 King St W                                      M5V 1J5              53.0
#                          Commerce Court, 199 Bay St                         M5L 1E2              28.0
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8               7.0
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3              16.0
#
#                                                                                          local_in_review
# name                     address                                            postal_code
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2             0.012048
# 00 Gelato                370 King Street W                                  M5V 1J9             0.015873
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3             0.010000
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9             0.000000
# 100 Percent Korean       4779 Steeles Avenue E                              M1V                 0.010363
# ...                                                                                                  ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8             0.000000
#                          327 King St W                                      M5V 1J5             0.000000
#                          Commerce Court, 199 Bay St                         M5L 1E2             0.000000
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8             0.000000
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3             0.000000
#
# [6407 rows x 5 columns]

# %%
df_restaurants.groupby(by = ['name', 'address', 'postal_code', 'attributes', 'categories']).mean()
# Out:
#                                                                                                                                                                                                 latitude  \
# name                     address                                            postal_code attributes                                         categories
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     {'RestaurantsTakeOut': 'True', 'WiFi': "'no'", ... Poke, Asian Fusion, Hawaiian, Food, Restaurants...  43.639526
# 00 Gelato                370 King Street W                                  M5V 1J9     {'WiFi': "u'no'", 'BikeParking': 'True', 'Wheel... Belgian, Waffles, Restaurants, Ice Cream & Froz...  43.646312
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     {'RestaurantsGoodForGroups': 'True', 'HasTV': '... Desserts, Cafes, Food, Specialty Food, Restaura...  43.814494
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     {'RestaurantsAttire': "'casual'", 'HasTV': 'Fal... Pizza, Restaurants, Food, Chicken Wings             43.597394
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         {'RestaurantsAttire': "u'casual'", 'Alcohol': "... Korean, Restaurants                                 43.825482
# ...                                                                                                                                                                                                  ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     {'Ambience': "{'romantic': False, 'intimate': F... Food Court, Restaurants, Fast Food, Tex-Mex, Me...  43.643090
#                          327 King St W                                      M5V 1J5     {'RestaurantsPriceRange2': '1', 'RestaurantsTak... Tex-Mex, Restaurants, Mexican                       43.646085
#                          Commerce Court, 199 Bay St                         M5L 1E2     {'Alcohol': "u'none'", 'OutdoorSeating': 'False... Restaurants, American (New), Fast Food, Gluten-...  43.648133
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     {'RestaurantsTakeOut': 'True', 'HasTV': 'False'... Restaurants, Mexican, Food Court, Fast Food, Te...  43.768778
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     {'RestaurantsReservations': 'False', 'Restauran... Restaurants, Tex-Mex, Fast Food, Mexican            43.778045
#
#                                                                                                                                                                                                longitude  \
# name                     address                                            postal_code attributes                                         categories
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     {'RestaurantsTakeOut': 'True', 'WiFi': "'no'", ... Poke, Asian Fusion, Hawaiian, Food, Restaurants... -79.415855
# 00 Gelato                370 King Street W                                  M5V 1J9     {'WiFi': "u'no'", 'BikeParking': 'True', 'Wheel... Belgian, Waffles, Restaurants, Ice Cream & Froz... -79.391329
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     {'RestaurantsGoodForGroups': 'True', 'HasTV': '... Desserts, Cafes, Food, Specialty Food, Restaura... -79.294924
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     {'RestaurantsAttire': "'casual'", 'HasTV': 'Fal... Pizza, Restaurants, Food, Chicken Wings            -79.520640
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         {'RestaurantsAttire': "u'casual'", 'Alcohol': "... Korean, Restaurants                                -79.298528
# ...                                                                                                                                                                                                  ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     {'Ambience': "{'romantic': False, 'intimate': F... Food Court, Restaurants, Fast Food, Tex-Mex, Me... -79.383072
#                          327 King St W                                      M5V 1J5     {'RestaurantsPriceRange2': '1', 'RestaurantsTak... Tex-Mex, Restaurants, Mexican                      -79.391092
#                          Commerce Court, 199 Bay St                         M5L 1E2     {'Alcohol': "u'none'", 'OutdoorSeating': 'False... Restaurants, American (New), Fast Food, Gluten-... -79.379509
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     {'RestaurantsTakeOut': 'True', 'HasTV': 'False'... Restaurants, Mexican, Food Court, Fast Food, Te... -79.413419
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     {'RestaurantsReservations': 'False', 'Restauran... Restaurants, Tex-Mex, Fast Food, Mexican           -79.495472
#
#                                                                                                                                                                                                stars_x  \
# name                     address                                            postal_code attributes                                         categories
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     {'RestaurantsTakeOut': 'True', 'WiFi': "'no'", ... Poke, Asian Fusion, Hawaiian, Food, Restaurants...      4.0
# 00 Gelato                370 King Street W                                  M5V 1J9     {'WiFi': "u'no'", 'BikeParking': 'True', 'Wheel... Belgian, Waffles, Restaurants, Ice Cream & Froz...      4.5
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     {'RestaurantsGoodForGroups': 'True', 'HasTV': '... Desserts, Cafes, Food, Specialty Food, Restaura...      3.5
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     {'RestaurantsAttire': "'casual'", 'HasTV': 'Fal... Pizza, Restaurants, Food, Chicken Wings                 2.0
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         {'RestaurantsAttire': "u'casual'", 'Alcohol': "... Korean, Restaurants                                     4.5
# ...                                                                                                                                                                                                ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     {'Ambience': "{'romantic': False, 'intimate': F... Food Court, Restaurants, Fast Food, Tex-Mex, Me...      2.5
#                          327 King St W                                      M5V 1J5     {'RestaurantsPriceRange2': '1', 'RestaurantsTak... Tex-Mex, Restaurants, Mexican                           2.5
#                          Commerce Court, 199 Bay St                         M5L 1E2     {'Alcohol': "u'none'", 'OutdoorSeating': 'False... Restaurants, American (New), Fast Food, Gluten-...      2.5
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     {'RestaurantsTakeOut': 'True', 'HasTV': 'False'... Restaurants, Mexican, Food Court, Fast Food, Te...      2.5
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     {'RestaurantsReservations': 'False', 'Restauran... Restaurants, Tex-Mex, Fast Food, Mexican                2.5
#
#                                                                                                                                                                                                review_count  \
# name                     address                                            postal_code attributes                                         categories
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     {'RestaurantsTakeOut': 'True', 'WiFi': "'no'", ... Poke, Asian Fusion, Hawaiian, Food, Restaurants...          82.0
# 00 Gelato                370 King Street W                                  M5V 1J9     {'WiFi': "u'no'", 'BikeParking': 'True', 'Wheel... Belgian, Waffles, Restaurants, Ice Cream & Froz...          61.0
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     {'RestaurantsGoodForGroups': 'True', 'HasTV': '... Desserts, Cafes, Food, Specialty Food, Restaura...         194.0
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     {'RestaurantsAttire': "'casual'", 'HasTV': 'Fal... Pizza, Restaurants, Food, Chicken Wings                      5.0
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         {'RestaurantsAttire': "u'casual'", 'Alcohol': "... Korean, Restaurants                                        191.0
# ...                                                                                                                                                                                                     ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     {'Ambience': "{'romantic': False, 'intimate': F... Food Court, Restaurants, Fast Food, Tex-Mex, Me...          10.0
#                          327 King St W                                      M5V 1J5     {'RestaurantsPriceRange2': '1', 'RestaurantsTak... Tex-Mex, Restaurants, Mexican                               53.0
#                          Commerce Court, 199 Bay St                         M5L 1E2     {'Alcohol': "u'none'", 'OutdoorSeating': 'False... Restaurants, American (New), Fast Food, Gluten-...          28.0
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     {'RestaurantsTakeOut': 'True', 'HasTV': 'False'... Restaurants, Mexican, Food Court, Fast Food, Te...           7.0
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     {'RestaurantsReservations': 'False', 'Restauran... Restaurants, Tex-Mex, Fast Food, Mexican                    16.0
#
#                                                                                                                                                                                                local_in_review
# name                     address                                            postal_code attributes                                         categories
# 'ONO Poké Bar            100 Western Battery Road, Unit 2                   M6K 3S2     {'RestaurantsTakeOut': 'True', 'WiFi': "'no'", ... Poke, Asian Fusion, Hawaiian, Food, Restaurants...         0.012048
# 00 Gelato                370 King Street W                                  M5V 1J9     {'WiFi': "u'no'", 'BikeParking': 'True', 'Wheel... Belgian, Waffles, Restaurants, Ice Cream & Froz...         0.015873
# 0109 Dessert & Chocolate 2190 McNicoll Avenue, Unit 109                     M1V 0B3     {'RestaurantsGoodForGroups': 'True', 'HasTV': '... Desserts, Cafes, Food, Specialty Food, Restaura...         0.010000
# 1 Plus 2 Pizza & Wings   3206 Lakeshore Blvd. W                             M8V 1L9     {'RestaurantsAttire': "'casual'", 'HasTV': 'Fal... Pizza, Restaurants, Food, Chicken Wings                    0.000000
# 100 Percent Korean       4779 Steeles Avenue E                              M1V         {'RestaurantsAttire': "u'casual'", 'Alcohol': "... Korean, Restaurants                                        0.010363
# ...                                                                                                                                                                                                        ...
# z-teca Gourmet Burritos  120 Bremner Boulevard, Food Court, 2nd Level       M5J 0A8     {'Ambience': "{'romantic': False, 'intimate': F... Food Court, Restaurants, Fast Food, Tex-Mex, Me...         0.000000
#                          327 King St W                                      M5V 1J5     {'RestaurantsPriceRange2': '1', 'RestaurantsTak... Tex-Mex, Restaurants, Mexican                              0.000000
#                          Commerce Court, 199 Bay St                         M5L 1E2     {'Alcohol': "u'none'", 'OutdoorSeating': 'False... Restaurants, American (New), Fast Food, Gluten-...         0.000000
#                          North York Centre Food Court, 5150 Yonge Street    M2N 6L8     {'RestaurantsTakeOut': 'True', 'HasTV': 'False'... Restaurants, Mexican, Food Court, Fast Food, Te...         0.000000
#                          York Lanes, York University, 4700 Keele Street,... M3J 1P3     {'RestaurantsReservations': 'False', 'Restauran... Restaurants, Tex-Mex, Fast Food, Mexican                   0.000000
#
# [6409 rows x 5 columns]
